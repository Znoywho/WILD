# %% [markdown]
# # Accessing document with

# %% [markdown]
# > Help to access document some syntaxes

# %%
help(len)
# Out:
# Help on built-in function len in module builtins:
#
# len(obj, /)
#     Return the number of items in a container.

# %%
len?
# Out:
# Signature: len(obj, /)
# Docstring: Return the number of items in a container.
# Type:      builtin_function_or_method

# %%
L = [1,2,3]
L.insert?
# Out:
# Signature: L.insert(index, object, /)
# Docstring: Insert object before index.
# Type:      builtin_function_or_method

# %%
L = [1,2,3]
L?
# Out:
# Type:        list
# String form: [1, 2, 3]
# Length:      3
# Docstring:
# Built-in mutable sequence.
#
# If no argument is given, the constructor creates a new empty list.
# The argument must be an iterable if specified.

# %%
def square(a):
    """Return square of a"""
    return a**2

# %%
square?
# Out:
# Signature: square(a)
# Docstring: Return square of a
# File:      c:\users\admin\appdata\local\temp\ipykernel_10836\498854444.py
# Type:      function

# %%
square??
# also show the code in function
# Out:
# Signature: square(a)
# Source:
# def square(a):
#     """Return square of a"""
#     return a**2
# File:      c:\users\admin\appdata\local\temp\ipykernel_10836\498854444.py
# Type:      function

# %%
len??
# Out:
# Signature: len(obj, /)
# Docstring: Return the number of items in a container.
# Type:      builtin_function_or_method

# %% [markdown]
# # Exporing Modules with Tab Completion

# %% [markdown]
# > ``` Python
# > import <TAB>
# > ```
# > choose library with suggestion

# %% [markdown]
# # IPython Magic Commands

# %%
def donothing(x):
    return x

# %%
# %run runtest.py
# Run file
# Out:
# 0
# 1
# 2

# %% [markdown]
# > calculate time for each loop

# %%
# %timeit L = [i**2 for i in range(1000)] # inline
# Out:
# 70.3 μs ± 3.3 μs per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
# %%timeit # codeblock
L = []
for i in range(1000):
    L.append(i**2)
# Out:
# 91.8 μs ± 9.34 μs per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# # ***DOCUMEMT*** of magic function

# %%
# %magic
# Out:
# IPython's 'magic' functions
# ...
#
# The magic function system provides a series of functions which allow you to
# control the behavior of IPython itself, plus a lot of system-type
# features. There are two kinds of magics, line-oriented and cell-oriented.
#
# Line magics are prefixed with the % character and work much like OS
# command-line calls: they get as an argument the rest of the line, where
# arguments are passed without parentheses or quotes.  For example, this will
# time the given statement::
#
#         %timeit range(1000)
#
# Cell magics are prefixed with a double %%, and they are functions that get as
# an argument not only the rest of the line, but also the lines below it in a
# separate argument.  These magics are called with two arguments: the rest of the
# call line and the body of the cell, consisting of the lines below the first.
# For example::
#
#         %%timeit x = numpy.random.randn((100, 100))
#         numpy.linalg.svd(x)
#
# ...

# %%
# %lsmagic
# Out:
# Available line magics:
# %alias  %alias_magic  %autoawait  %autocall  %automagic  %autosave  %bookmark  %cd  %clear  %cls  %code_wrap  %colors  %conda  %config  %connect_info  %copy  %ddir  %debug  %dhist  %dirs  %doctest_mode  %echo  %ed  %edit  %env  %gui  %hist  %history  %killbgscripts  %ldir  %less  %load  %load_ext  %loadpy  %logoff  %logon  %logstart  %logstate  %logstop  %ls  %lsmagic  %macro  %magic  %mamba  %matplotlib  %micromamba  %mkdir  %more  %notebook  %page  %pastebin  %pdb  %pdef  %pdoc  %pfile  %pinfo  %pinfo2  %pip  %popd  %pprint  %precision  %prun  %psearch  %psource  %pushd  %pwd  %pycat  %pylab  %qtconsole  %quickref  %recall  %rehashx  %reload_ext  %ren  %rep  %rerun  %reset  %reset_selective  %rmdir  %run  %save  %sc  %set_env  %store  %subshell  %sx  %system  %tb  %time  %timeit  %unalias  %unload_ext  %uv  %who  %who_ls  %whos  %xdel  %xmode
#
# Available cell magics:
# ...

# %% [markdown]
# # INPUT AND OUTPUT HISTORY

# %%
import math

# %%
math.sin(2)
# Out:
# 0.9092974268256817

# %%
math.sin(3)
# Out:
# 0.1411200080598672

# %%
print(In[11])
# Out:
# import math

# %%
print(Out[12],Out[13])
# Out:
# 0.9092974268256817 0.1411200080598672

# %% [markdown]
# ## Underscore Shortcuts and Previous Output

# %%
print(_)
# Out:
# 0.1411200080598672

# %% [markdown]
# > Want more further output just add more underscore

# %%
print(__)
# Out:
# 0.9092974268256817

# %% [markdown]
# ## LIST all your code text

# %%
# %history
# Out:
# %run runtest.py
# %run runtest.py
# # Run file
# %timeit L = [i**2 for i in range(1000)]
# %timeit L = [i**2 for i in range(1000)]
# %%timeit# codeblock
# L = []
# for i in range(1000):
#     L.append(i**2)
# %%timeit # codeblock
# L = []
# for i in range(1000):
#     L.append(i**2)
# %magiv
# %magic
# %lsmagic
# # INPUT AND OUTPUT HISTORY
# import math
# math.sin(2)
# math.sin(3)
# print(In)
# print(In[11])
# print(Out)
# print(Out[12:13])
# print(Out[12],Out[13])
# print(_)
# print(__)
# %history

# %%
# %history -n 1-3
# Out:
#    1: %run runtest.py
#    2:
# %run runtest.py
# # Run file
#    3: %timeit L = [i**2 for i in range(1000)]

# %% [markdown]
# - ***Use TERMINAL***

# %%
# !dir
# Out:
#  Volume in drive D is DATASSD
#  Volume Serial Number is 9A7A-D940
#
#  Directory of D:\begin\Anaconda\NOTEBOOK\WILD\DATASCIENCE
#
# 26/01/2026  08:53 CH    <DIR>          .
# 26/01/2026  08:53 CH    <DIR>          ..
# 26/01/2026  08:17 CH    <DIR>          .ipynb_checkpoints
# 26/01/2026  08:53 CH           157.057 Beyond_Normal_Python.ipynb
# 25/01/2026  08:43 SA               782 Introduction_to_NumPy.ipynb
# 24/01/2026  08:08 CH        22.321.280 Python Data Science Handbook.pdf
# 26/01/2026  08:18 CH                31 runtest.py
#                4 File(s)     22.479.150 bytes
#                3 Dir(s)  633.172.832.256 bytes free

# %%
import os 
os.listdir(".")
# Out:
# ['.ipynb_checkpoints',
#  'Beyond_Normal_Python.ipynb',
#  'Introduction_to_NumPy.ipynb',
#  'Python Data Science Handbook.pdf',
#  'runtest.py']

# %%
# %pwd
# Out:
# 'D:\\begin\\Anaconda\\NOTEBOOK\\WILD\\DATASCIENCE'

# %%
# !echo {"HELLO"}
# Out:
# HELLO

# %% [markdown]
# # DEBUGGING

# %%
# %xmode
data = [89,9,29,2]
for i in range(len(data)):
    for j in range(len(data)- i - 1):
        if (data[j] > data[j + 1]):
            data[j],data[j+1] = data[j+1],data[j]
print(data)
# Out:
# Exception reporting mode: Minimal
# [2, 9, 29, 89]

# %% [markdown]
# - Minimal Exceptation
# - Have 3 modes:
#     - Plain
#     - Verbose

# %%
# %debug
data = [89,9,29,2]
for i in range(len(data)):
    for j in range(len(ata)- i - 1):
        if (data[j] > data[j + 1]):
            data[j],data[j+1] = data[j+1],data[j]
print(data)
# Out:
# > c:\users\admin\appdata\local\temp\ipykernel_1392\331477777.py(4)<module>()
# ipdb>
# Traceback (most recent call last):
#
#   Cell In[44], line 4
#     for j in range(len(ata)- i - 1):
#
# NameError: name 'ata' is not defined

# %%
def func(a,b):
    return a/b

# %%
# %xmode Plain
# %pdb on
func(1,0)
# Out:
# Exception reporting mode: Plain
# Automatic pdb calling has been turned ON
# Traceback (most recent call last):
#
#   Cell In[49], line 3
#     func(1,0)
#
#   Cell In[48], line 2 in func
#     return a/b
#
# ZeroDivisionError: division by zero
# > c:\users\admin\appdata\local\temp\ipykernel_1392\2595194763.py(2)func()
# ipdb>  up
# > c:\users\admin\appdata\local\temp\ipykernel_1392\2448574008.py(3)<module>()
# ipdb>  down
# > c:\users\admin\appdata\local\temp\ipykernel_1392\2595194763.py(2)func()
# ipdb>  down
# *** Newest frame
# ipdb>  down
# *** Newest frame
# ipdb>  clear
# Clear all breaks?  clear all break
# ipdb>  down
# *** Newest frame
# ipdb>  down
# *** Newest frame
# ipdb>  quit

# %%
# %%timeit
total = 0
for i in range(1000):
    for j in range(1000):
        total += i * (-1) ** j
# Out:
# 185 ms ± 10.5 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
import random
L = [random.random() for i in range(100000)]
print("sorting an unsorted list:")
# %time L.sort()
# Out:
# sorting an unsorted list:
# CPU times: total: 31.2 ms
# Wall time: 29.9 ms

# %%
def sum_of_lists(N):
    total = 0
    for i in range(5):
        L = [j ^ (j >> i) for j in range(N)]
        total += sum(L)
    return total
# %prun sum_of_lists(1000)
# Out:
#          9 function calls in 0.001 seconds
#
#    Ordered by: internal time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.001    0.001    0.001    0.001 1776300784.py:1(sum_of_lists)
#         1    0.000    0.000    0.001    0.001 {built-in method builtins.exec}
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#         5    0.000    0.000    0.000    0.000 {built-in method builtins.sum}
#         1    0.000    0.000    0.001    0.001 <string>:1(<module>)

# %%
# !pip install line_profiler

# %%
# %load_ext line_profiler

# %%
# %lprun -f sum_of_lists sum_of_lists(5000)
# Out:
# Timer unit: 1e-07 s
#
# Total time: 0.0047831 s
# File: C:\Users\ADMIN\AppData\Local\Temp\ipykernel_15500\1776300784.py
# Function: sum_of_lists at line 1
#
# Line #      Hits         Time  Per Hit   % Time  Line Contents
# ...
#      1                                           def sum_of_lists(N):
#      2         1         37.0     37.0      0.1      total = 0
#      3         6        160.0     26.7      0.3      for i in range(5):
#      4         5      44135.0   8827.0     92.3          L = [j ^ (j >> i) for j in range(N)]
#      5         5       3368.0    673.6      7.0          total += sum(L)
#      6         1        131.0    131.0      0.3      return total

# %%
# !pip install memory_profiler
# Out:
# ...
#   Using cached memory_profiler-0.61.0-py3-none-any.whl.metadata (20 kB)
# ...
# Using cached memory_profiler-0.61.0-py3-none-any.whl (31 kB)
# ...

# %%
# %load_ext memory_profiler
# Out:
# The memory_profiler extension is already loaded. To reload it, use:
#   %reload_ext memory_profiler

# %%
# %memit sum_of_lists(1000)
# Out:
# peak memory: 93.34 MiB, increment: 0.00 MiB

# %% [markdown]
# ![image.png](attachment:2eec1e8f-79fe-4a9c-9f58-8a0ea764ded2.png)
# ![image.png](attachment:d1553a40-1a7d-401b-8ae2-037aba3e0daf.png)

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 print("khanh oc cac", "12",step = "")
#
# TypeError: print() got an unexpected keyword argument 'step'. Did you mean 'sep'?
